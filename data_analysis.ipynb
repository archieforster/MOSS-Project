# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
journeytimes = pd.read_csv('./outputs/journey_metrics_p1000_evp0.17_tick0.25.csv')
evacdata = pd.read_csv('./outputs/gy-evac (3) test2-table.csv', skiprows=6)

journeytimes['norm_journey_time'] = journeytimes['actual_time'] / journeytimes['ideal_time']

#journeytimes.head()
evacdata.head()
# Out:
#    [run number]  over-break-p  initial-people  evacuation-probability  \
# 0             1          0.06            1000                    0.17
# 1             1          0.06            1000                    0.17
# 2             1          0.06            1000                    0.17
# 3             1          0.06            1000                    0.17
# 4             1          0.06            1000                    0.17
#
#    tick-time-in-mins  max-walk-distance-km  [step]  \
# 0               0.25                     0       0
# 1               0.25                     0       1
# 2               0.25                     0       2
# 3               0.25                     0       3
# 4               0.25                     0       4
#
#                          ticks    get-avg-no-people-per-car  \
# 0  <RuntimePrimitiveException>  <WrappedExtensionException>
# 1  <RuntimePrimitiveException>  <WrappedExtensionException>
# ...

# %% [markdown]
# # Journey Times

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(journeytimes['norm_journey_time'], bins=40, density=True)
ax.set_title('Histogram of normalised journey times')
ax.set_xlabel('Normalised journey time')
ax.set_ylabel('Frequency')

plt.show()
